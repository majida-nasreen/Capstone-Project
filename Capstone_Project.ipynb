# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## Credit Card Customer Analysis

# %% [markdown]
# ### Exploratory Data Analysis(EDA)

# %% [markdown]
# #### Import required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Supressing warnings for better readability

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing the dataset

# %%
df=pd.read_csv(r"C:\Users\admin\Downloads\Capstone_Project(Majida)\BankChurners.csv")

# %% [markdown]
# ##### Check the first few rows

# %%
df.head()

# %% [markdown]
# ##### Check Rows and Columns

# %%
df.shape

# %% [markdown]
# ##### Fetch column names

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %% [markdown]
# ##### Check data types and missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [markdown]
# ##### Count misssing values per column

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %% [markdown]
# ##### Statistical summary of numerical features

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# ##### Check duplicated values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Dropped non-informative  columns to reduce noise and improve model efficiency

# %%
df.drop(columns=['CLIENTNUM','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
                          'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],inplace=True)

# %%
df
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# ##### Filter Out 'Unknown' Values

# %%
df=df[(df['Income_Category']!='Unknown')&(df['Education_Level']!='Unknown')]

# %% [markdown]
# #### plots

# %% [markdown]
# ##### Visulaizes customer churn distribution

# %%
AF=sns.countplot(x=df['Attrition_Flag'],palette="coolwarm")
for container in AF.containers:
    AF.bar_label(container)
plt.title("Churn vs Active Customers")
plt.show()

# %% [markdown]
# ##### Gender  Distribution by Churn

# %%
G=sns.countplot(data=df,x='Gender',hue="Attrition_Flag",palette="pastel")
for container in G.containers:
    G.bar_label(container)
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Customer Churn Distribution by Gender")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### Education_Level  Distribution by Churn

# %%
EL=sns.countplot(data=df,x='Education_Level',hue="Attrition_Flag",palette="Set2")
for container in EL.containers:
    EL.bar_label(container)
plt.xlabel("Education_Level")
plt.ylabel("Count")
plt.title("Customer Churn Distribution by Education_Level")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### Marital_Status  Distribution by Churn

# %%
MS=sns.countplot(data=df,x='Marital_Status',hue="Attrition_Flag",palette="pastel")
for container in MS.containers:
   MS.bar_label(container)
plt.xlabel("Marital_Status")
plt.ylabel("Count")
plt.title("Customer Churn Distribution by Marital_Status")
plt.show()

# %% [markdown]
# ##### Income_Category  Distribution by Churn

# %%
IC=sns.countplot(data=df,x='Income_Category',hue="Attrition_Flag",palette="pastel")
for container in IC.containers:
    IC.bar_label(container)
plt.xlabel("Income_Category")
plt.ylabel("Count")
plt.title("Customer Churn Distribution by Income_Category")
plt.show()

# %% [markdown]
# ##### Card_Category  Distribution by Churn

# %%
CC=sns.countplot(data=df,x='Card_Category',hue="Attrition_Flag",palette="Set2")
for container in CC.containers:
    CC.bar_label(container)
plt.xlabel("Card_Category")
plt.ylabel("Count")
plt.title("Customer Churn Distribution by Card_Category")
plt.show()

# %% [markdown]
# ##### Customer_Age Distribution

# %%
plt.figure(figsize=(10,8))
sns.histplot(df["Customer_Age"],kde=True,bins=10,color="blue")
plt.xlabel("Customer_Age")
plt.ylabel("Count")
plt.title("Distribution of Customer_Age")
plt.show()

# %% [markdown]
# ##### Months on Books Distribution

# %%
plt.figure(figure=(10,6))
sns.histplot(df["Months_on_book"],kde=True,bins=10,color="purple")
plt.xlabel("months_on_books")
plt.ylabel("Count")
plt.title("Distribution of Customer Tenure")
plt.show()

# %%
##### Credit_Limit Distribution

# %%
plt.figure(figure=(10,6))
sns.histplot(df["Credit_Limit"],kde=True,bins=10,color="orange")
plt.xlabel("Credit_Limit")
plt.ylabel("Count")
plt.title("Distribution of Credit_Limit")
plt.show()

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ##### categorising  col for further labelling

# %%
df['Attrition_Flag']=df['Attrition_Flag'].astype('category')
df['Gender']=df['Gender'].astype('category')
df['Education_Level']=df['Education_Level'].astype('category')
df['Marital_Status']=df['Marital_Status'].astype('category')
df['Income_Category']=df['Income_Category'].astype('category')
df['Card_Category']=df['Card_Category'].astype('category')

# %% [markdown]
# ##### labelling the cols

# %%
df['Attrition_Flag']=df['Attrition_Flag'].cat.codes
df['Gender']=df['Gender'].cat.codes
df['Education_Level']=df['Education_Level'].cat.codes
df['Marital_Status']=df['Marital_Status'].cat.codes
df['Income_Category']=df['Income_Category'].cat.codes
df['Card_Category']=df['Card_Category'].cat.codes

# %% [markdown]
# ##### Identifies strong correlation between variables

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Features Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### splitting data

# %%
X=df[['Customer_Age','Gender','Dependent_count',
    'Education_Level','Marital_Status','Income_Category','Card_Category',
    'Months_on_book','Total_Relationship_Count','Months_Inactive_12_mon',
    'Contacts_Count_12_mon','Credit_Limit','Total_Revolving_Bal',
    'Avg_Open_To_Buy','Total_Amt_Chng_Q4_Q1','Total_Trans_Amt',
    'Total_Trans_Ct','Total_Ct_Chng_Q4_Q1','Avg_Utilization_Ratio']]

# %%
y=df[['Attrition_Flag']]

# %% [markdown]
# ### Model Building

# %% [markdown]
# ##### Splitting data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ##### Feature sacling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
classifiers=[
    LogisticRegression(random_state = 0),
    RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0),
    SVC(kernel = 'linear', random_state = 0),
    KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)]
name=[]    
score=[]
models=[]

i = 0
for classifier in classifiers:
    classifier.fit(X_train,y_train)
    name.append(type(classifier).__name__)
    score.append(classifier.score(X_test,y_test))
    models.append(classifier)

# %% [markdown]
# ##### Comparing model performance

# %%
df_score=pd.DataFrame(list(zip(name,score,models)),columns=['name','score','models'])
df_score.set_index('name',inplace=True)                      
df_score.sort_values(by=['score'],inplace=True)
df_score
# Out:
#                            score  \
# name
# LogisticRegression      0.892740
# SVC                     0.895356
# KNeighborsClassifier    0.897319
# RandomForestClassifier  0.949640
#
#                                                                    models
# name
# LogisticRegression                     LogisticRegression(random_state=0)
# SVC                                  SVC(kernel='linear', random_state=0)
# KNeighborsClassifier                               KNeighborsClassifier()
# RandomForestClassifier  (DecisionTreeClassifier(criterion='entropy', m...

# %% [markdown]
# ##### Prediction

# %%
RFC_model=RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
RFC_model.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
X_test.shape
# Out:
# (1529, 19)

# %%
y_pred_RFC=RFC_model.predict(X_test)
y_pred_RFC
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int8)

# %%
cm = confusion_matrix(y_test,y_pred_RFC)
print(cm)
accuracy_score(y_test,y_pred_RFC)
print('classification report:\n',classification_report(y_test,y_pred_RFC))
# Out:
# [[ 212   48]
#  [  29 1240]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85       260
#            1       0.96      0.98      0.97      1269
#
#     accuracy                           0.95      1529
#    macro avg       0.92      0.90      0.91      1529
# weighted avg       0.95      0.95      0.95      1529

# %%
plt.figure(figsize=(5,4))
sns.heatmap(cm,annot=True,fmt="d",cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Metrix")
plt.show()

# %% [markdown]
# ### Thank You
